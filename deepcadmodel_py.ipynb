# %%
import torch
import torch.nn as nn
import math
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json

# %%
import kagglehub

path = kagglehub.dataset_download("vitalygladyshev/deepcad")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/vitalygladyshev/deepcad/versions/1

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
#Device Agnostic Code

# %%
class CADModel(nn.Module): #model class CADmodel
  {


  }
